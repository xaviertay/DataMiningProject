# %%
import glob
import numpy as np
import pandas as pd

# %%
path = r'D:\Desktop\Data Mining\unstructured' # use your path
all_files = glob.glob(path + "/*.csv")

# %%
li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame = frame.drop_duplicates()
frame["date"]= frame["date"].str.replace("10:48 PM", "1 Sep 2019")

# %%
frame['date'] = pd.to_datetime(frame.date)
frame = frame.sort_values(by='date')

# %%
frame
# Out:
#                                                 title       date
# 18  Hurricane Dorian: Trump flies to golf club as ... 2019-09-01
# 16  Hurricane Dorian: where will the storm hit and... 2019-09-01
# 15  A chilling truth: our addiction to air conditi... 2019-09-01
# 19  Hurricane Dorian strengthens to category 4 as ... 2019-09-01
# 17  Floridians not fazed as Hurricane Dorian’s pat... 2019-09-01
# 13  Hurricane Dorian: millions evacuated from coas... 2019-09-02
# 14  Hurricane Dorian lashes Bahamas with ferocious... 2019-09-02
# 11  Hurricane Dorian: 'We're at the frontline of c... 2019-09-05
# 12  'Sharpiegate': Trump insists Dorian was foreca... 2019-09-05
# 10  'Everything is destroyed': 30 dead in Bahamas ... 2019-09-06
# 9   Hurricane Dorian: 70,000 in 'immediate need of... 2019-09-06
# 8   'Sharpiegate': meteorologists upset as weather... 2019-09-07
# 7   Top weather official who defended 'Sharpiegate... 2019-09-10
# ...

# %%
export_csv = frame.to_csv (r'D:\Desktop\Unstructured_Data.csv', index = None, header=True)
